# %%
def payment(debt):
    pay = debt/5
    return pay


def interest(debt):
    monthsinterest = debt * 4.25/100
    return monthsinterest


debt = 30057
months = 6
total_pays = 0
total_interest = 0
for i in range(months):

    interesti = interest(debt)
    total_interest += interesti
    int_debt = interesti + debt

    paymenti = payment(int_debt)
    if paymenti <= 6000:
        paymenti = 6000

    if paymenti >= debt:
        paymenti = debt

    
    total_pays+= paymenti
    
    leftover_debt = int_debt - paymenti
    if leftover_debt < 100:
        break

    print(f"\n\nMonth {i+1}: \nInitial debt = {debt}\nInterest + debt = {int_debt}\nPayment = {paymenti}\nLeftover debt = {leftover_debt}")
    debt = leftover_debt
    print(f"\nTotal payments so far = {total_pays}\nTotal interest = {total_interest}")
# Out:
# Month 1:
# Initial debt = 30057
# Interest + debt = 31334.4225
# Payment = 6266.8845
# Leftover debt = 25067.538
#
# Total payments so far = 6266.8845
# Total interest = 1277.4225
#
#
# Month 2:
# Initial debt = 25067.538
# Interest + debt = 26132.908365
# Payment = 6000
# Leftover debt = 20132.908365
#
# Total payments so far = 12266.8845
# Total interest = 2342.792865
#
#
# Month 3:
# Initial debt = 20132.908365
# Interest + debt = 20988.556970512498
# Payment = 6000
# Leftover debt = 14988.556970512498
#
# Total payments so far = 18266.8845
# Total interest = 3198.4414705125
#
#
# Month 4:
# Initial debt = 14988.556970512498
# Interest + debt = 15625.57064175928
# Payment = 6000
# Leftover debt = 9625.57064175928
#
# Total payments so far = 24266.8845
# Total interest = 3835.455141759281
#
#
# Month 5:
# Initial debt = 9625.57064175928
# Interest + debt = 10034.657394034048
# Payment = 6000
# Leftover debt = 4034.6573940340477
#
# Total payments so far = 30266.8845
# ...

# %%
30057+30057*4.25/100
# Out:
# 31334.4225
